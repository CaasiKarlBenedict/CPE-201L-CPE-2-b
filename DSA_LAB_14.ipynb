# %% [markdown]
# <a href="https://colab.research.google.com/github/CaasiKarlBenedict/CPE-201L-CPE-2-b/blob/main/DSA_LAB_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class TreeNode:
    def __init__(self, value):
        self.value = value
        self.children = []

    def add_child(self, child_node):
        self.children.append(child_node)

    # Post-order traversal: visit children first, then node
    def post_order_traversal(self):
        for child in self.children:
            child.post_order_traversal()
        print(f"Deleting node {self.value}")
        # Here you can add deletion logic if needed (like freeing resources)

# Create a sample tree and delete it properly
root = TreeNode("Root")
child1 = TreeNode("Child 1")
child2 = TreeNode("Child 2")
grandchild1 = TreeNode("Grandchild 1")
grandchild2 = TreeNode("Grandchild 2")

root.add_child(child1)
root.add_child(child2)
child1.add_child(grandchild1)
child2.add_child(grandchild2)

print("Post-order deletion traversal:")
root.post_order_traversal()
# Out:
# Post-order deletion traversal:
# Deleting node Grandchild 1
# Deleting node Child 1
# Deleting node Grandchild 2
# Deleting node Child 2
# Deleting node Root
